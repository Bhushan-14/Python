# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhushan-14/Python/blob/main/Python_13_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e1bf484-8d16-415d-a270-2f985f30dcee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e1bf484-8d16-415d-a270-2f985f30dcee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

data = pd.read_csv(io.BytesIO(uploaded['SacramentocrimeJanuary2006.csv']))
print(data)
# Out:
#           cdatetime                            address  district        beat  \
# 0       1/1/06 0:00                 3108 OCCIDENTAL DR         3  3C
# 1       1/1/06 0:00                2082 EXPEDITION WAY         5  5A
# 2       1/1/06 0:00                         4 PALEN CT         2  2A
# 3       1/1/06 0:00                     22 BECKFORD CT         6  6C
# 4       1/1/06 0:00                   3421 AUBURN BLVD         2  2A
# ...             ...                                ...       ...         ...
# 7579  1/31/06 23:36                     26TH ST / G ST         3  3B
# 7580  1/31/06 23:40                 4011 FREEPORT BLVD         4  4A
# 7581  1/31/06 23:41                     30TH ST / K ST         3  3C
# 7582  1/31/06 23:45                 5303 FRANKLIN BLVD         4  4B
# 7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR         4  4C
#
#       grid                     crimedescr  ucr_ncic_code   latitude  \
# ...

# %%
data.head()
# Out:
#      cdatetime              address  district        beat  grid  \
# 0  1/1/06 0:00   3108 OCCIDENTAL DR         3  3C          1115
# 1  1/1/06 0:00  2082 EXPEDITION WAY         5  5A          1512
# 2  1/1/06 0:00           4 PALEN CT         2  2A           212
# 3  1/1/06 0:00       22 BECKFORD CT         6  6C          1443
# 4  1/1/06 0:00     3421 AUBURN BLVD         2  2A           508
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 0  10851(A)VC TAKE VEH W/O OWNER           2404  38.550420 -121.391416
# 1     459 PC  BURGLARY RESIDENCE           2204  38.473501 -121.490186
# 2  10851(A)VC TAKE VEH W/O OWNER           2404  38.657846 -121.462101
# 3   476 PC PASS FICTICIOUS CHECK           2501  38.506774 -121.426951
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7584 entries, 0 to 7583
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cdatetime      7584 non-null   object
#  1   address        7584 non-null   object
#  2   district       7584 non-null   int64
#  3   beat           7584 non-null   object
#  4   grid           7584 non-null   int64
#  5   crimedescr     7584 non-null   object
#  6   ucr_ncic_code  7584 non-null   int64
#  7   latitude       7584 non-null   float64
#  8   longitude      7584 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 533.4+ KB

# %%
data.shape
# Out:
# (7584, 9)

# %%
data['district'].value_counts().sort_values()
# Out:
# 1     868
# 5    1159
# 4    1161
# 6    1359
# 2    1462
# 3    1575
# Name: district, dtype: int64

# %%
data.tail()
# Out:
#           cdatetime                            address  district        beat  \
# 7579  1/31/06 23:36                     26TH ST / G ST         3  3B
# 7580  1/31/06 23:40                 4011 FREEPORT BLVD         4  4A
# 7581  1/31/06 23:41                     30TH ST / K ST         3  3C
# 7582  1/31/06 23:45                 5303 FRANKLIN BLVD         4  4B
# 7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR         4  4C
#
#       grid                     crimedescr  ucr_ncic_code   latitude  \
# 7579   728  594(B)(2)(A) VANDALISM/ -$400           2999  38.577832
# 7580   957      459 PC  BURGLARY BUSINESS           2203  38.537591
# 7581   841        TRAFFIC-ACCIDENT INJURY           5400  38.572030
# 7582   969        3056 PAROLE VIO - I RPT           7000  38.527187
# 7583  1294    TRAFFIC-ACCIDENT-NON INJURY           5400  38.479628
#
#        longitude
# 7579 -121.470460
# 7580 -121.492591
# 7581 -121.467012
# 7582 -121.471248
# 7583 -121.528634

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dc4257af-14d6-4866-b862-9bbd68a0037c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dc4257af-14d6-4866-b862-9bbd68a0037c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
data = pd.read_csv("annual.csv",nrows = 10)
data
# Out:
#    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2019                     Level 1                 99999
# 1  2019                     Level 1                 99999
# 2  2019                     Level 1                 99999
# 3  2019                     Level 1                 99999
# 4  2019                     Level 1                 99999
# 5  2019                     Level 1                 99999
# 6  2019                     Level 1                 99999
# 7  2019                     Level 1                 99999
# 8  2019                     Level 1                 99999
# 9  2019                     Level 1                 99999
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# ...

# %%
data = pd.read_csv("annual.csv",usecols = ['Variable_code','Variable_name','Variable_category'])
data
# Out:
#       Variable_code                                    Variable_name  \
# 0               H01                                     Total income
# 1               H04  Sales, government funding, grants and subsidies
# 2               H05                Interest, dividends and donations
# 3               H07                             Non-operating income
# 4               H08                                Total expenditure
# ...             ...                                              ...
# 32440           H37                                      Quick ratio
# 32441           H38              Margin on sales of goods for resale
# 32442           H39                                 Return on equity
# 32443           H40                           Return on total assets
# 32444           H41                            Liabilities structure
#
#            Variable_category
# 0      Financial performance
# 1      Financial performance
# 2      Financial performance
# ...

# %%
data = pd.read_csv("annual.csv",header = None)
data
# Out:
#           0                            1                     2  \
# 0      Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1      2019                      Level 1                 99999
# 2      2019                      Level 1                 99999
# 3      2019                      Level 1                 99999
# 4      2019                      Level 1                 99999
# ...     ...                          ...                   ...
# 32441  2013                      Level 3                  ZZ11
# 32442  2013                      Level 3                  ZZ11
# 32443  2013                      Level 3                  ZZ11
# 32444  2013                      Level 3                  ZZ11
# 32445  2013                      Level 3                  ZZ11
#
#                                 3                   4              5  \
# 0            Industry_name_NZSIOC               Units  Variable_code
# ...

# %%
data = pd.read_csv("/content/SacramentocrimeJanuary2006.csv")
print(data)
# Out:
#           cdatetime                            address  district        beat  \
# 0       1/1/06 0:00                 3108 OCCIDENTAL DR         3  3C
# 1       1/1/06 0:00                2082 EXPEDITION WAY         5  5A
# 2       1/1/06 0:00                         4 PALEN CT         2  2A
# 3       1/1/06 0:00                     22 BECKFORD CT         6  6C
# 4       1/1/06 0:00                   3421 AUBURN BLVD         2  2A
# ...             ...                                ...       ...         ...
# 7579  1/31/06 23:36                     26TH ST / G ST         3  3B
# 7580  1/31/06 23:40                 4011 FREEPORT BLVD         4  4A
# 7581  1/31/06 23:41                     30TH ST / K ST         3  3C
# 7582  1/31/06 23:45                 5303 FRANKLIN BLVD         4  4B
# 7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR         4  4C
#
#       grid                     crimedescr  ucr_ncic_code   latitude  \
# ...

# %%
data.describe()
# Out:
#           district         grid  ucr_ncic_code     latitude    longitude
# count  7584.000000  7584.000000    7584.000000  7584.000000  7584.000000
# mean      3.574631   916.250791    4275.068829    38.559809  -121.463832
# std       1.642512   407.436310    2171.593193     0.056101     0.034621
# min       1.000000   102.000000     909.000000    38.437999  -121.555832
# 25%       2.000000   567.000000    2309.000000    38.518476  -121.489543
# 50%       3.000000   899.000000    3532.000000    38.559523  -121.465459
# 75%       5.000000  1264.000000    7000.000000    38.610361  -121.435947
# max       6.000000  1661.000000    8102.000000    38.683789  -121.365238

# %%
data.describe(include = 'all')
# Out:
#           cdatetime           address     district        beat         grid  \
# count          7584              7584  7584.000000        7584  7584.000000
# unique         5094              5492          NaN          20          NaN
# top     1/1/06 0:01  3555 AUBURN BLVD          NaN  2B                  NaN
# freq             24                47          NaN         521          NaN
# mean            NaN               NaN     3.574631         NaN   916.250791
# std             NaN               NaN     1.642512         NaN   407.436310
# min             NaN               NaN     1.000000         NaN   102.000000
# 25%             NaN               NaN     2.000000         NaN   567.000000
# 50%             NaN               NaN     3.000000         NaN   899.000000
# 75%             NaN               NaN     5.000000         NaN  1264.000000
# max             NaN               NaN     6.000000         NaN  1661.000000
#
# ...

# %%
data
# Out:
#           cdatetime                            address  district        beat  \
# 0       1/1/06 0:00                 3108 OCCIDENTAL DR         3  3C
# 1       1/1/06 0:00                2082 EXPEDITION WAY         5  5A
# 2       1/1/06 0:00                         4 PALEN CT         2  2A
# 3       1/1/06 0:00                     22 BECKFORD CT         6  6C
# 4       1/1/06 0:00                   3421 AUBURN BLVD         2  2A
# ...             ...                                ...       ...         ...
# 7579  1/31/06 23:36                     26TH ST / G ST         3  3B
# 7580  1/31/06 23:40                 4011 FREEPORT BLVD         4  4A
# 7581  1/31/06 23:41                     30TH ST / K ST         3  3C
# 7582  1/31/06 23:45                 5303 FRANKLIN BLVD         4  4B
# 7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR         4  4C
#
#       grid                     crimedescr  ucr_ncic_code   latitude  \
# ...

# %%
data[data['district']==1]
# Out:
#           cdatetime                  address  district        beat  grid  \
# 9       1/1/06 0:00        1326 HELMSMAN WAY         1  1B           444
# 35      1/1/06 0:01           4851 KOKOMO DR         1  1A           123
# 36      1/1/06 0:01      2377 OAK HARBOUR DR         1  1B           440
# 39      1/1/06 0:01          3301 ARENA BLVD         1  1A           303
# 40      1/1/06 0:01           1088 PREGO WAY         1  1B           404
# ...             ...                      ...       ...         ...   ...
# 7506  1/31/06 17:35           720 NORTHEY DR         1  1C           447
# 7507  1/31/06 17:38       3301 FONG RANCH RD         1  1B           404
# 7513  1/31/06 18:00  POTOMAC AVE / NATOMA ST         1  1C           419
# 7517  1/31/06 18:14          300 HARDING AVE         1  1C           449
# 7523  1/31/06 19:00     1301 W EL CAMINO AVE         1  1B           435
#
#                           crimedescr  ucr_ncic_code   latitude   longitude
# ...
