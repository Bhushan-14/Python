# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhushan-14/Python/blob/main/Python_14_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("d:\\SacramentocrimeJanuary2006.csv")

# %%
#display all column name
data.columns
# Out:
# Index(['cdatetime', 'address', 'district', 'beat', 'grid', 'crimedescr',
#        'ucr_ncic_code', 'latitude', 'longitude'],
#       dtype='object')

# %%
#selection
#Returns column with label col as Series
data['address']
# Out:
# 0                          3108 OCCIDENTAL DR
# 1                         2082 EXPEDITION WAY
# 2                                  4 PALEN CT
# 3                              22 BECKFORD CT
# 4                            3421 AUBURN BLVD
# 5                          5301 BONNIEMAE WAY
# 6                               2217 16TH AVE
# 7                                   3547 P ST
# 8                            3421 AUBURN BLVD
# 9                           1326 HELMSMAN WAY
# 10                         2315 STOCKTON BLVD
# 11                               5112 63RD ST
# 12                          6351 DRIFTWOOD ST
# 13                       7721 COLLEGE TOWN DR
# 14                            8460 ROVANA CIR
# 15                              4856 11TH AVE
# 16                               6033 69TH ST
# 17                                   547 L ST
# 18                               3525 42ND ST
# 19                            5641 DORSET WAY
# ...

# %%
#Returns columns as a new DataFrame : selecting multipule columns
data[['address','district']]
# Out:
#                                     address  district
# 0                        3108 OCCIDENTAL DR         3
# 1                       2082 EXPEDITION WAY         5
# 2                                4 PALEN CT         2
# 3                            22 BECKFORD CT         6
# 4                          3421 AUBURN BLVD         2
# 5                        5301 BONNIEMAE WAY         6
# 6                             2217 16TH AVE         4
# 7                                 3547 P ST         3
# 8                          3421 AUBURN BLVD         2
# 9                         1326 HELMSMAN WAY         1
# 10                       2315 STOCKTON BLVD         6
# 11                             5112 63RD ST         6
# 12                        6351 DRIFTWOOD ST         4
# 13                     7721 COLLEGE TOWN DR         3
# 14                          8460 ROVANA CIR         6
# 15                            4856 11TH AVE         6
# ...

# %%
#Selection by position from series
data.iloc[1]
# Out:
# cdatetime                       1/1/06 0:00
# address                 2082 EXPEDITION WAY
# district                                  5
# beat                             5A
# grid                                   1512
# crimedescr       459 PC  BURGLARY RESIDENCE
# ucr_ncic_code                          2204
# latitude                            38.4735
# longitude                           -121.49
# Name: 1, dtype: object

# %%
# retrieving row by loc method : 2nd row
data.loc[2:5]
# Out:
#      cdatetime             address  district        beat  grid  \
# 2  1/1/06 0:00          4 PALEN CT         2  2A           212
# 3  1/1/06 0:00      22 BECKFORD CT         6  6C          1443
# 4  1/1/06 0:00    3421 AUBURN BLVD         2  2A           508
# 5  1/1/06 0:00  5301 BONNIEMAE WAY         6  6B          1084
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 2  10851(A)VC TAKE VEH W/O OWNER           2404  38.657846 -121.462101
# 3   476 PC PASS FICTICIOUS CHECK           2501  38.506774 -121.426951
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613
# 5  530.5 PC USE PERSONAL ID INFO           2604  38.526979 -121.451338

# %%
# retrieving row by iloc method
data.iloc[2]
# Out:
# cdatetime                          1/1/06 0:00
# address                             4 PALEN CT
# district                                     2
# beat                                2A
# grid                                       212
# crimedescr       10851(A)VC TAKE VEH W/O OWNER
# ucr_ncic_code                             2404
# latitude                               38.6578
# longitude                             -121.462
# Name: 2, dtype: object

# %%
# retrieving rows by loc method
data.iloc[[4, 5, 6, 7]]
# Out:
#      cdatetime             address  district        beat  grid  \
# 4  1/1/06 0:00    3421 AUBURN BLVD         2  2A           508
# 5  1/1/06 0:00  5301 BONNIEMAE WAY         6  6B          1084
# 6  1/1/06 0:00       2217 16TH AVE         4  4A           957
# 7  1/1/06 0:00           3547 P ST         3  3C           853
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613
# 5  530.5 PC USE PERSONAL ID INFO           2604  38.526979 -121.451338
# 6       459 PC  BURGLARY VEHICLE           2299  38.537173 -121.487577
# 7    484 PC   PETTY THEFT/INSIDE           2308  38.564335 -121.461883

# %%
# retrieving rows by loc method
data.iloc[4:8]
# Out:
#      cdatetime             address  district        beat  grid  \
# 4  1/1/06 0:00    3421 AUBURN BLVD         2  2A           508
# 5  1/1/06 0:00  5301 BONNIEMAE WAY         6  6B          1084
# 6  1/1/06 0:00       2217 16TH AVE         4  4A           957
# 7  1/1/06 0:00           3547 P ST         3  3C           853
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613
# 5  530.5 PC USE PERSONAL ID INFO           2604  38.526979 -121.451338
# 6       459 PC  BURGLARY VEHICLE           2299  38.537173 -121.487577
# 7    484 PC   PETTY THEFT/INSIDE           2308  38.564335 -121.461883

# %%
#select a column using iloc
#iloc[rows,columns]
#iloc[start:end,start:end]
#here all row of 1st column
data.iloc[:,1]
# Out:
# 0                          3108 OCCIDENTAL DR
# 1                         2082 EXPEDITION WAY
# 2                                  4 PALEN CT
# 3                              22 BECKFORD CT
# 4                            3421 AUBURN BLVD
# 5                          5301 BONNIEMAE WAY
# 6                               2217 16TH AVE
# 7                                   3547 P ST
# 8                            3421 AUBURN BLVD
# 9                           1326 HELMSMAN WAY
# 10                         2315 STOCKTON BLVD
# 11                               5112 63RD ST
# 12                          6351 DRIFTWOOD ST
# 13                       7721 COLLEGE TOWN DR
# 14                            8460 ROVANA CIR
# 15                              4856 11TH AVE
# 16                               6033 69TH ST
# 17                                   547 L ST
# 18                               3525 42ND ST
# 19                            5641 DORSET WAY
# ...

# %%
#sorting data frame by Year
# by default ascending order
data.sort_values('district')
# Out:
#           cdatetime                          address  district        beat  \
# 4367  1/18/06 22:00             1671 W EL CAMINO AVE         1  1B
# 1425    1/7/06 0:30                4601 BLACKROCK DR         1  1A
# 1420    1/7/06 0:01                   5948 MEEKS WAY         1  1A
# 1411    1/7/06 0:00                  3260 NORDYKE DR         1  1C
# 1409    1/7/06 0:00              3410 SHADOW TREE DR         1  1B
# 1405   1/6/06 23:30                  1911 BANDON WAY         1  1B
# 1399   1/6/06 22:49               3224 NORTHSTEAD DR         1  1C
# 1392   1/6/06 22:30               1510 PEBBLEWOOD DR         1  1C
# 1391   1/6/06 22:26                   3561 TRUXEL RD         1  1A
# 6550  1/27/06 17:45                  3285 AZEVEDO DR         1  1B
# 1383   1/6/06 22:00                  6 SOUTHBURY WAY         1  1A
# 6552  1/27/06 17:46               3301 FONG RANCH RD         1  1B
# 4873  1/20/06 20:00               1570 WATERWHEEL DR         1  1B
# ...

# %%
#sorting data frame by Year in descending order
data.sort_values('district',ascending=False)
# Out:
#           cdatetime                            address  district        beat  \
# 5428  1/23/06 10:44                   3012 REDDING AVE         6  6C
# 1134   1/5/06 20:15           16TH AVE / STOCKTON BLVD         6
# 2313  1/10/06 22:00                        1 CLAUSS CT         6  6B
# 6064  1/25/06 19:30                       4592 58TH ST         6  6B
# 4418   1/19/06 7:46                    130 PRAIRIE CIR         6  6C
# 2316  1/10/06 22:00                 8155 BELVEDERE AVE         6  6C
# 2318  1/10/06 22:15           ALHAMBRA BLVD / BROADWAY         6  6A
# 6071  1/25/06 20:00                       5408 56TH ST         6  6B
# 1126   1/5/06 20:00                3015 SAN CARLOS WAY         6  6A
# 6072  1/25/06 20:13                      4609 13TH AVE         6  6A
# 2320  1/10/06 22:23                  2ND AVE / 57TH ST         6  6B
# 4413   1/19/06 6:31                 6351 GLENHILLS WAY         6  6C
# ...

# %%
#Makes the changes in passed data frame itself if True
#data.sort_values('Year',inplace=True)

# %%
#Based on Multipile column
data.sort_values(['Year','Industry_aggregation_NZSIOC'])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27810  2013                     Level 1                99999
# 27811  2013                     Level 1                99999
# 27812  2013                     Level 1                99999
# 27813  2013                     Level 1                99999
# 27814  2013                     Level 1                99999
# ...     ...                         ...                  ...
# 4594   2019                     Level 4                RS214
# 4595   2019                     Level 4                RS214
# 4596   2019                     Level 4                RS214
# 4597   2019                     Level 4                RS214
# 4598   2019                     Level 4                RS214
#
#                                 Industry_name_NZSIOC               Units  \
# 27810                                 All industries  Dollars (millions)
# 27811                                 All industries  Dollars (millions)
# ...

# %%
#Filtring
data
# Out:
#           cdatetime                            address  district        beat  \
# 0       1/1/06 0:00                 3108 OCCIDENTAL DR         3  3C
# 1       1/1/06 0:00                2082 EXPEDITION WAY         5  5A
# 2       1/1/06 0:00                         4 PALEN CT         2  2A
# 3       1/1/06 0:00                     22 BECKFORD CT         6  6C
# 4       1/1/06 0:00                   3421 AUBURN BLVD         2  2A
# ...             ...                                ...       ...         ...
# 7579  1/31/06 23:36                     26TH ST / G ST         3  3B
# 7580  1/31/06 23:40                 4011 FREEPORT BLVD         4  4A
# 7581  1/31/06 23:41                     30TH ST / K ST         3  3C
# 7582  1/31/06 23:45                 5303 FRANKLIN BLVD         4  4B
# 7583  1/31/06 23:50  COBBLE COVE LN / COBBLE SHORES DR         4  4C
#
#       grid                     crimedescr  ucr_ncic_code   latitude  \
# ...

# %%
data[(data['district']==2)&(data['beat']=="2A")]
# Out:
# Empty DataFrame
# Columns: [cdatetime, address, district, beat, grid, crimedescr, ucr_ncic_code, latitude, longitude]
# Index: []

# %%
data[(data['Year']==2014) | (data['Industry_aggregation_NZSIOC']=='Level 3')]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 62     2019                     Level 3                 AA11
# 63     2019                     Level 3                 AA11
# 64     2019                     Level 3                 AA11
# 65     2019                     Level 3                 AA11
# 66     2019                     Level 3                 AA11
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#                  Industry_name_NZSIOC               Units Variable_code  \
# 62     Horticulture and Fruit Growing  Dollars (millions)           H01
# 63     Horticulture and Fruit Growing  Dollars (millions)           H04
# ...

# %%
#count occurrences of each value
data['Year'].value_counts()
# Out:
# 2015    4635
# 2014    4635
# 2013    4635
# 2019    4635
# 2018    4635
# 2017    4635
# 2016    4635
# Name: Year, dtype: int64

# %%
#creating a bool series from isin()
#return True if Variable_code has value H14
#data['Variable_code'].isin(['H14'])
#data['Year'].isin(['2019'])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 32440    False
# 32441    False
# 32442    False
# 32443    False
# 32444    False
# Name: Year, Length: 32445, dtype: bool

# %%
df=pd.read_csv('annual-enterprise-survey-2019-financial-year-provisional-csv .csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32445 entries, 0 to 32444
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         32445 non-null  int64
#  1   Industry_aggregation_NZSIOC  32445 non-null  object
#  2   Industry_code_NZSIOC         32445 non-null  object
#  3   Industry_name_NZSIOC         32445 non-null  object
#  4   Units                        32445 non-null  object
#  5   Variable_code                32445 non-null  object
#  6   Variable_name                32445 non-null  object
#  7   Variable_category            32445 non-null  object
#  8   Value                        32445 non-null  object
#  9   Industry_code_ANZSIC06       32445 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.5+ MB

# %%
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df[(df['Industry_aggregation_NZSIOC']=="Level 1") & (df['Variable_code']=='H01')]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 31     2019                     Level 1                   AA
# 425    2019                     Level 1                   BB
# 458    2019                     Level 1                   CC
# 1676   2019                     Level 1                   DD
# ...     ...                         ...                  ...
# 31395  2013                     Level 1                   MN
# 31758  2013                     Level 1                   OO
# 31851  2013                     Level 1                   PP
# 32001  2013                     Level 1                   QQ
# 32121  2013                     Level 1                   RS
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...
