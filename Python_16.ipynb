# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhushan-14/Python/blob/main/Python_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_path = "JhonsMustang.png"

original_image = Image.open(image_path)

plt.imshow(original_image)
plt.axis('off')
plt.show()

# %%
scale_percent = 200  # adjust the scale factor as needed
width = int(original_image.width * scale_percent / 100)
height = int(original_image.height * scale_percent / 100)
resized_image = original_image.resize((width, height))

# %%
plt.imshow(resized_image)
plt.axis('off')
plt.show()

# %%
from PIL import Image, ImageDraw, ImageFont

image_path = "JhonsMustang.png"
original_image = cv2.imread(image_path)

if original_image is not None:
    pil_image = Image.fromarray(original_image)

    # Create a transparent overlay
    overlay = Image.new('RGBA', pil_image.size, (255, 255, 255, 0))
    draw = ImageDraw.Draw(overlay)

    # Use a larger font size
    font_size = 500
    font = ImageFont.load_default()

    text = "Hello, I'm Jhon Wicks Mustang!"
    position = (200, 50)

    draw.text(position, text, fill=(255, 255, 255, 255), font=font)

    # Composite the overlay on the original image
    result_image = Image.alpha_composite(pil_image.convert('RGBA'), overlay)

    plt.imshow(result_image)
    plt.axis('off')
    plt.show()
else:
    print("Error loading the image.")

# %%
gray_image = original_image.convert('L')

plt.imshow(gray_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
angle = 180
rotated_image = original_image.rotate(angle)

plt.imshow(rotated_image)
plt.axis('off')
plt.show()

# %%
from PIL import ImageFilter

blurred_image = original_image.filter(ImageFilter.BLUR)

plt.imshow(blurred_image)
plt.axis('off')
plt.show()
