# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhushan-14/Python/blob/main/Python_15_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame([[1,"Amit",34],[2,'Deepak',23]],columns=['id','name',"age"])

# %%
df
# Out:
#    id    name  age
# 0   1    Amit   34
# 1   2  Deepak   23

# %%
df.to_csv("fromdf.csv",index=False)
#df.to_excel("file")

# %%
df1=pd.read_csv("d:\\SacramentocrimeJanuary2006.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7584 entries, 0 to 7583
# Data columns (total 9 columns):
# cdatetime        7584 non-null object
# address          7584 non-null object
# district         7584 non-null int64
# beat             7584 non-null object
# grid             7584 non-null int64
# crimedescr       7584 non-null object
# ucr_ncic_code    7584 non-null int64
# latitude         7584 non-null float64
# longitude        7584 non-null float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 533.3+ KB

# %%
df1.head()
# Out:
#      cdatetime              address  district        beat  grid  \
# 0  1/1/06 0:00   3108 OCCIDENTAL DR         3  3C          1115
# 1  1/1/06 0:00  2082 EXPEDITION WAY         5  5A          1512
# 2  1/1/06 0:00           4 PALEN CT         2  2A           212
# 3  1/1/06 0:00       22 BECKFORD CT         6  6C          1443
# 4  1/1/06 0:00     3421 AUBURN BLVD         2  2A           508
#
#                       crimedescr  ucr_ncic_code   latitude   longitude
# 0  10851(A)VC TAKE VEH W/O OWNER           2404  38.550420 -121.391416
# 1     459 PC  BURGLARY RESIDENCE           2204  38.473501 -121.490186
# 2  10851(A)VC TAKE VEH W/O OWNER           2404  38.657846 -121.462101
# 3   476 PC PASS FICTICIOUS CHECK           2501  38.506774 -121.426951
# 4   459 PC  BURGLARY-UNSPECIFIED           2299  38.637448 -121.384613

# %%
df1.isna().sum()
# Out:
# cdatetime        0
# address          0
# district         0
# beat             0
# grid             0
# crimedescr       0
# ucr_ncic_code    0
# latitude         0
# longitude        0
# dtype: int64

# %%
#np.unique(df1['district'])
df1['district'].unique()
# Out:
# array([3, 5, 2, 6, 4, 1], dtype=int64)

# %%
df1['district'].value_counts()
# Out:
# 3    1575
# 2    1462
# 6    1359
# 4    1161
# 5    1159
# 1     868
# Name: district, dtype: int64

# %%
#df1.apply(pd.Series.value_counts)

# %%
df2=pd.read_csv("d:\\COVIDclinicaltrials.csv",header=None)

# %%
df2
# Out:
#         0            1                                                  2   \
# 0     Rank   NCT Number                                              Title
# 1        1  NCT04395924         Maternal-foetal Transmission of SARS-Cov-2
# 2        2  NCT04395482  Lung CT Scan Analysis of SARS-CoV2 Induced Lun...
# 3        3  NCT04367805  COVID-19 Infection in Patients With Hepatocell...
# 4        4  NCT04427332     Smell and Taste Disorders in COVID-19 Patients
# 5        5  NCT04407585  Testing the Accuracy of a Digital Test to Diag...
# 6        6  NCT04403672  Performance Evaluation of RealDetect™ COVID-19...
# 7        7  NCT04372004  Comparison of the Efficacy of Rapid Tests to I...
# 8        8  NCT04416061  The Role of a Private Hospital in Hong Kong Am...
# 9        9  NCT04386109  Neonatal Complications of Coronavirus Disease ...
# 10      10  NCT04424004  MURDOCK Cabarrus County COVID-19 Prevalence an...
# ...

# %%
df1.describe()
# Out:
#           district         grid  ucr_ncic_code     latitude    longitude
# count  7584.000000  7584.000000    7584.000000  7584.000000  7584.000000
# mean      3.574631   916.250791    4275.068829    38.559809  -121.463832
# std       1.642512   407.436310    2171.593193     0.056101     0.034621
# min       1.000000   102.000000     909.000000    38.437999  -121.555832
# 25%       2.000000   567.000000    2309.000000    38.518476  -121.489543
# 50%       3.000000   899.000000    3532.000000    38.559523  -121.465459
# 75%       5.000000  1264.000000    7000.000000    38.610361  -121.435947
# max       6.000000  1661.000000    8102.000000    38.683789  -121.365238

# %%
df1.sort_values('district')
# Out:
#           cdatetime                          address  district        beat  \
# 4367  1/18/06 22:00             1671 W EL CAMINO AVE         1  1B
# 1425    1/7/06 0:30                4601 BLACKROCK DR         1  1A
# 1420    1/7/06 0:01                   5948 MEEKS WAY         1  1A
# 1411    1/7/06 0:00                  3260 NORDYKE DR         1  1C
# 1409    1/7/06 0:00              3410 SHADOW TREE DR         1  1B
# 1405   1/6/06 23:30                  1911 BANDON WAY         1  1B
# 1399   1/6/06 22:49               3224 NORTHSTEAD DR         1  1C
# 1392   1/6/06 22:30               1510 PEBBLEWOOD DR         1  1C
# 1391   1/6/06 22:26                   3561 TRUXEL RD         1  1A
# 6550  1/27/06 17:45                  3285 AZEVEDO DR         1  1B
# 1383   1/6/06 22:00                  6 SOUTHBURY WAY         1  1A
# 6552  1/27/06 17:46               3301 FONG RANCH RD         1  1B
# 4873  1/20/06 20:00               1570 WATERWHEEL DR         1  1B
# ...

# %%
df1.sort_values('district',ascending=False)
# Out:
#           cdatetime                            address  district        beat  \
# 5428  1/23/06 10:44                   3012 REDDING AVE         6  6C
# 1134   1/5/06 20:15           16TH AVE / STOCKTON BLVD         6
# 2313  1/10/06 22:00                        1 CLAUSS CT         6  6B
# 6064  1/25/06 19:30                       4592 58TH ST         6  6B
# 4418   1/19/06 7:46                    130 PRAIRIE CIR         6  6C
# 2316  1/10/06 22:00                 8155 BELVEDERE AVE         6  6C
# 2318  1/10/06 22:15           ALHAMBRA BLVD / BROADWAY         6  6A
# 6071  1/25/06 20:00                       5408 56TH ST         6  6B
# 1126   1/5/06 20:00                3015 SAN CARLOS WAY         6  6A
# 6072  1/25/06 20:13                      4609 13TH AVE         6  6A
# 2320  1/10/06 22:23                  2ND AVE / 57TH ST         6  6B
# 4413   1/19/06 6:31                 6351 GLENHILLS WAY         6  6C
# ...

# %%
df2=pd.read_csv("d:\\annual.csv")

# %%
df2.sort_values('Year',ascending=False)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 3043   2019                     Level 3                 JJ11
# 3095   2019                     Level 1                   KK
# 3094   2019                     Level 1                   KK
# 3093   2019                     Level 1                   KK
# 3092   2019                     Level 1                   KK
# 3091   2019                     Level 1                   KK
# 3090   2019                     Level 1                   KK
# 3089   2019                     Level 1                   KK
# 3088   2019                     Level 1                   KK
# 3087   2019                     Level 1                   KK
# 3086   2019                     Level 1                   KK
# 3085   2019                     Level 3                 JJ12
# 3084   2019                     Level 3                 JJ12
# ...

# %%
df2.sort_values(['Year','Value'])
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 28662  2013                     Level 3                 CC41
# 28698  2013                     Level 4                CC411
# 29083  2013                     Level 3                 CC71
# 29119  2013                     Level 4                CC711
# 28589  2013                     Level 3                 CC32
# 28625  2013                     Level 4                CC321
# 28645  2013                     Level 3                 CC41
# 28681  2013                     Level 4                CC411
# 30097  2013                     Level 4                FF116
# 29088  2013                     Level 3                 CC71
# 29124  2013                     Level 4                CC711
# 28657  2013                     Level 3                 CC41
# 28693  2013                     Level 4                CC411
# 28573  2013                     Level 3                 CC32
# ...

# %%
df2['Variable_code'].value_counts()
# Out:
# H40    973
# H05    973
# H12    973
# H21    973
# H07    973
# H41    973
# H24    973
# H09    973
# H10    973
# H20    973
# H39    973
# H22    973
# H08    973
# H01    973
# H11    973
# H31    973
# H13    973
# H23    973
# H30    973
# H36    938
# H33    938
# H37    938
# H25    938
# H26    938
# H29    938
# H32    938
# H35    889
# H34    889
# H28    840
# H06    840
# H27    840
# H19    609
# H04    546
# H02    364
# H03    364
# H38    364
# H18    364
# H17    364
# H14    119
# Name: Variable_code, dtype: int64

# %%
a=df1['grid'].head()
a
# Out:
# 0    1115
# 1    1512
# 2     212
# 3    1443
# 4     508
# Name: grid, dtype: int64

# %%
a.astype(float)
# Out:
# 0    1115.0
# 1    1512.0
# 2     212.0
# 3    1443.0
# 4     508.0
# Name: grid, dtype: float64

# %%
df1
# Out:
#           cdatetime                                address  district  \
# 0       1/1/06 0:00                     3108 OCCIDENTAL DR         3
# 1       1/1/06 0:00                    2082 EXPEDITION WAY         5
# 2       1/1/06 0:00                             4 PALEN CT         2
# 3       1/1/06 0:00                         22 BECKFORD CT         6
# 4       1/1/06 0:00                       3421 AUBURN BLVD         2
# 5       1/1/06 0:00                     5301 BONNIEMAE WAY         6
# 6       1/1/06 0:00                          2217 16TH AVE         4
# 7       1/1/06 0:00                              3547 P ST         3
# 8       1/1/06 0:00                       3421 AUBURN BLVD         2
# 9       1/1/06 0:00                      1326 HELMSMAN WAY         1
# 10      1/1/06 0:00                     2315 STOCKTON BLVD         6
# 11      1/1/06 0:00                           5112 63RD ST         6
# 12      1/1/06 0:00                      6351 DRIFTWOOD ST         4
# ...

# %%
df1['district'].replace(1,100).head(20)
# Out:
# 0       3
# 1       5
# 2       2
# 3       6
# 4       2
# 5       6
# 6       4
# 7       3
# 8       2
# 9     100
# 10      6
# 11      6
# 12      4
# 13      3
# 14      6
# 15      6
# 16      6
# 17      3
# 18      6
# 19      4
# Name: district, dtype: int64

# %%
df2.isna().sum()
# Out:
# Year                           0
# Industry_aggregation_NZSIOC    0
# Industry_code_NZSIOC           0
# Industry_name_NZSIOC           0
# Units                          0
# Variable_code                  0
# Variable_name                  0
# Variable_category              0
# Value                          0
# Industry_code_ANZSIC06         0
# dtype: int64

# %%
df3=pd.read_csv("d:\\COVIDclinicaltrials.csv")

# %%
df3.isna().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    1378
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               414
# Outcome Measures             22
# Sponsor/Collaborators         0
# Gender                        5
# Age                           0
# Phases                     1127
# Enrollment                   22
# Funded Bys                    0
# Study Type                    0
# Study Designs                23
# Other IDs                     1
# Start Date                   22
# Primary Completion Date      23
# Completion Date              23
# First Posted                  0
# Results First Posted       2594
# Last Update Posted            0
# Locations                   418
# Study Documents            2547
# URL                           0
# dtype: int64

# %%
en=df3['Gender']

# %%
en.unique()
# Out:
# array(['Female', 'All', 'change_value', 'Male'], dtype=object)

# %%
en.replace(np.nan,'change_value',inplace=True)
en
# Out:
# 0       Female
# 1          All
# 2          All
# 3          All
# 4          All
# 5          All
# 6          All
# 7          All
# 8          All
# 9          All
# 10         All
# 11         All
# 12      Female
# 13         All
# 14         All
# 15         All
# 16         All
# 17         All
# 18         All
# 19         All
# 20         All
# 21         All
# 22         All
# 23         All
# 24         All
# 25         All
# 26      Female
# 27         All
# 28         All
# 29         All
#          ...
# 2565      Male
# 2566       All
# 2567       All
# 2568       All
# 2569       All
# 2570       All
# 2571      Male
# 2572      Male
# 2573       All
# 2574       All
# 2575       All
# 2576       All
# 2577       All
# 2578       All
# 2579       All
# 2580       All
# 2581       All
# 2582       All
# 2583      Male
# 2584    Female
# 2585       All
# 2586      Male
# 2587       All
# 2588       All
# 2589       All
# 2590    Female
# 2591       All
# ...

# %%
en.unique()
# Out:
# array(['Female', 'All', 'change_value', 'Male'], dtype=object)

# %%
df3.isna().sum()
# Out:
# Rank                          0
# NCT Number                    0
# Title                         0
# Acronym                    1378
# Status                        0
# Study Results                 0
# Conditions                    0
# Interventions               414
# Outcome Measures             22
# Sponsor/Collaborators         0
# Gender                        0
# Age                           0
# Phases                     1127
# Enrollment                   22
# Funded Bys                    0
# Study Type                    0
# Study Designs                23
# Other IDs                     1
# Start Date                   22
# Primary Completion Date      23
# Completion Date              23
# First Posted                  0
# Results First Posted       2594
# Last Update Posted            0
# Locations                   418
# Study Documents            2547
# URL                           0
# dtype: int64

# %%
#b.replace(np.nan,"abc")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-b5f7edd59d13> in <module>()
# ----> 1 b.replace(np.nan,"abc")
#
# NameError: name 'b' is not defined

# %%
df1.rename(columns={'district':'District_name'},inplace=True)

# %%
df1
# Out:
#           cdatetime                                address  District_name  \
# 0       1/1/06 0:00                     3108 OCCIDENTAL DR              3
# 1       1/1/06 0:00                    2082 EXPEDITION WAY              5
# 2       1/1/06 0:00                             4 PALEN CT              2
# 3       1/1/06 0:00                         22 BECKFORD CT              6
# 4       1/1/06 0:00                       3421 AUBURN BLVD              2
# 5       1/1/06 0:00                     5301 BONNIEMAE WAY              6
# 6       1/1/06 0:00                          2217 16TH AVE              4
# 7       1/1/06 0:00                              3547 P ST              3
# 8       1/1/06 0:00                       3421 AUBURN BLVD              2
# 9       1/1/06 0:00                      1326 HELMSMAN WAY              1
# 10      1/1/06 0:00                     2315 STOCKTON BLVD              6
# 11      1/1/06 0:00                           5112 63RD ST              6
# ...

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df3 = pd.DataFrame(d1)

d2 = {"Name": ["Pankaj"], "ID": [1], "Role": ["CEO"]}
df4=pd.DataFrame(d2)

# %%
df3
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
df4
# Out:
#      Name  ID Role
# 0  Pankaj   1  CEO

# %%
df2=pd.concat([df3,df4],ignore_index=True)

# %%
df2
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author
# 3  Pankaj   1     CEO

# %%
d3={"city":['Delhi','Noida','Aligarh','Agra']}
df4=pd.DataFrame(d3)

# %%
df5=pd.concat([df2,df4],axis=1)

# %%
df5
# Out:
#      Name  age  ID    Role     city
# 0  Pankaj   23   1     CEO    Delhi
# 1    Lisa   45   2  Editor    Noida
# 2   David   23   3  Author  Aligarh
# 3  Pankaj   56   1     CEO     Agra

# %%
df5.insert(0,'age',[23,45,23,56])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-82-8fd12c4735da> in <module>()
# ----> 1 df5.insert(0,'age',[23,45,23,56])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3217         value = self._sanitize_column(column, value, broadcast=False)
#    3218         self._data.insert(loc, column, value,
# -> 3219                           allow_duplicates=allow_duplicates)
#    3220
#    3221     def assign(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# -> 4338             raise ValueError('cannot insert {}, already exists'.format(item))
# ...

# %%
df5.insert(2,'age1',[23,45,23,56])

# %%
df5
# Out:
#      Name  age  age1  ID    Role     city
# 0  Pankaj   23    23   1     CEO    Delhi
# 1    Lisa   45    45   2  Editor    Noida
# 2   David   23    23   3  Author  Aligarh
# 3  Pankaj   56    56   1     CEO     Agra

# %%
df5.drop_duplicates(subset=['age'])
# Out:
#      Name  age  age1  ID    Role   city
# 0  Pankaj   23    23   1     CEO  Delhi
# 1    Lisa   45    45   2  Editor  Noida
# 3  Pankaj   56    56   1     CEO   Agra

# %%
df5
# Out:
#      Name  age  age1  ID    Role     city
# 0  Pankaj   23    23   1     CEO    Delhi
# 1    Lisa   45    45   2  Editor    Noida
# 2   David   23    23   3  Author  Aligarh
# 3  Pankaj   56    56   1     CEO     Agra

# %%
df2=pd.read_csv("d:\\SacramentocrimeJanuary2006.csv")

# %%
df2.sample(n=100)
# Out:
#           cdatetime                            address  district        beat  \
# 7040  1/29/06 21:00               838 RANCHO ROBLE WAY         1  1C
# 7288  1/30/06 19:08                    4100 ASTORIA ST         2  2A
# 5328  1/22/06 22:00                     1689 ARDEN WAY         2  2C
# 5780  1/24/06 16:52               1514A MCALLISTER AVE         4  4C
# 5116  1/21/06 22:17                       1380 57TH ST         3  3C
# 4586  1/19/06 19:00                     18TH ST / K ST         3  3M
# 5139   1/22/06 0:00                       3701 55TH ST         6  6B
# 6235  1/26/06 13:47  LOS ROBLES BLVD / MARYSVILLE BLVD         2  2B
# 4418   1/19/06 7:46                    130 PRAIRIE CIR         6  6C
# 1906    1/9/06 9:00                         720 9TH ST         3  3A
# 2970   1/13/06 8:45        SEAMAS AVE / RIVERSIDE BLVD         4  4A
# 2232  1/10/06 16:00          GREENHAVEN DR / FLORIN RD         4  4C
# ...

# %%
df2.sample(frac=0.20)
# Out:
#           cdatetime                        address  district        beat  \
# 4412   1/19/06 6:30                1121 COMMONS DR         3  3C
# 4040  1/17/06 19:30              2925 CAMARILLO DR         1  1C
# 2103   1/10/06 0:01                 3200 TRUXEL RD         1  1C
# 1194    1/6/06 1:19           6220 BELLEAU WOOD LN         4  4C
# 2026   1/9/06 17:51                  6 KLONDIKE CT         1  1A
# 6495  1/27/06 14:25                 25TH ST / T ST         3  3B
# 5908   1/25/06 9:00              1861 GLENROSE AVE         2  2C
# 1452    1/7/06 3:30                    2 KELSO CIR         1  1C
# 3446   1/15/06 7:00               3418 JUMILLA WAY         1  1A
# 2887  1/12/06 21:00                      6 INCA CT         1  1C
# 4836  1/20/06 17:40                  5500 19TH AVE         6  6B
# 5285  1/22/06 18:33                 16TH ST / C ST         3  3A
# 5633   1/24/06 7:59       FRANKLIN BLVD / 13TH AVE         4  4B
# ...

# %%
d1 = {"Name": ["Pankaj", "Lisa", "David"], "ID": [1, 2, 3], "Role": ["CEO", "Editor", "Author"]}
df1 = pd.DataFrame(d1)

d2 = {"Name": ["Amit", "Deepak", "Ram"], "ID": [4, 2, 6], "Role": ["CEO", "Sales", "Marketing"]}
df2 = pd.DataFrame(d2)

# %%
pd.merge(df1,df2,on='ID',how='inner')
# Out:
#   Name_x  ID  Role_x  Name_y Role_y
# 0   Lisa   2  Editor  Deepak  Sales

# %%
pd.merge(df1,df2,on='ID',how='left')
# Out:
#    Name_x  ID  Role_x  Name_y Role_y
# 0  Pankaj   1     CEO     NaN    NaN
# 1    Lisa   2  Editor  Deepak  Sales
# 2   David   3  Author     NaN    NaN

# %%
df1
# Out:
#      Name  ID    Role
# 0  Pankaj   1     CEO
# 1    Lisa   2  Editor
# 2   David   3  Author

# %%
df2
# Out:
#      Name  ID       Role
# 0    Amit   4        CEO
# 1  Deepak   2      Sales
# 2     Ram   6  Marketing

# %%
pd.merge(df1,df2,on='ID',how="inner")
# Out:
#   Name_x  ID  Role_x  Name_y Role_y
# 0   Lisa   2  Editor  Deepak  Sales

# %%
pd.merge(df1,df2,on='ID',how="left")
# Out:
#    Name_x  ID  Role_x  Name_y Role_y
# 0  Pankaj   1     CEO     NaN    NaN
# 1    Lisa   2  Editor  Deepak  Sales
# 2   David   3  Author     NaN    NaN

# %%
pd.merge(df1,df2,on='ID',how="right")
# Out:
#   Name_x  ID  Role_x  Name_y     Role_y
# 0   Lisa   2  Editor  Deepak      Sales
# 1    NaN   4     NaN    Amit        CEO
# 2    NaN   6     NaN     Ram  Marketing

# %%
pd.merge(df1,df2,on='ID',how="outer")
# Out:
#    Name_x  ID  Role_x  Name_y     Role_y
# 0  Pankaj   1     CEO     NaN        NaN
# 1    Lisa   2  Editor  Deepak      Sales
# 2   David   3  Author     NaN        NaN
# 3     NaN   4     NaN    Amit        CEO
# 4     NaN   6     NaN     Ram  Marketing
